# %%
import numpy as np
import pandas as pd
from arch import arch_model
from statsmodels.tsa.stattools import adfuller
import pandas as pd

df = pd.read_csv('CryptoTableauData.csv')
df.head(10)
df_bitcoin = df[df['crypto_name'] == 'Bitcoin']
df_bitcoin.head()

df_ret = pd.read_csv('CryptoReturnsData.csv')
df_ret = df_ret.drop(['trade_date'], axis=1)
df_ret = df_ret.dropna()
df_ret_abs = df_ret.abs()
df_ret.head()

df_logret = pd.read_csv('CryptoLogReturnsData.csv')
df_logret = df_logret.drop(['trade_date'], axis=1)
df_logret = df_logret.dropna()
df_logret_abs = df_logret.abs()
df_logret.head()

df_vol = pd.read_csv('CryptoVolumeData.csv')
df_vol = df_vol.drop(['trade_date'], axis=1)
df_vol = df_vol.dropna()
#df_vol = df_vol.abs()
df_vol.head()
# Out:
#    Binance_Coin    Bitcoin  Bitcoin_Cash  Bitcoin_SV       Cardano  Chainlink  \
# 0    13595933.0  2285901.0     8260875.0   4913763.0  1.109614e+09   32612915
# 1    12725873.0  2277170.0     8908406.0   4778668.0  9.123387e+08   39574860
# 2    14481198.0  2806769.0     8478598.0   5295787.0  1.458810e+09   45666041
# 3    12719992.0  2793752.0     7750431.0   5026660.0  1.892762e+09   44377600
# 4    11626864.0  2473762.0     8063560.0   4282231.0  1.607080e+09   56364011
#
#    Crypto_com_Coin          EOS    Ethereum  Huobi_Token    Litecoin  \
# 0        393131898  554819091.0  43968425.0   27610043.0  57244277.0
# 1        383223801  528716218.0  47823167.0   27839594.0  55616064.0
# 2        624589389  779468280.0  57224534.0   29730444.0  69298745.0
# 3        597677920  876575966.0  53368351.0   29452557.0  75693466.0
# 4        617465025  669064411.0  53330141.0   41762497.0  58873479.0
#
#       Monero         NEO       Stellar       Tether       Tezos          TRON  \
# 0  3110149.0  49121561.0  4.091794e+09  23973071925  11407697.0  4.278287e+10
# 1  4016523.0  41989830.0  4.423396e+09  24597499287  13197268.0  4.307836e+10
# 2  3247277.0  47475221.0  4.775886e+09  30710349697  18755269.0  4.902068e+10
# 3  4651344.0  45056169.0  9.623521e+09  30721581637  14756402.0  4.501190e+10
# 4  4072668.0  41137525.0  4.384331e+09  28578448466  26804412.0  4.993091e+10
#
#    UNUS_SED_LEO   USD_Coin           XRP
# 0       6863967  222754025  4.959182e+09
# 1       7477121  208342328  4.702822e+09
# 2       9116221  310602968  5.573760e+09
# 3      12641495  294667615  6.534276e+09
# 4      13814759  254889570  5.857837e+09

# %%
def adfuller_test(series, signif=0.05):
    x = adfuller(series, autolag='AIC')

    #using dictionary saves different data types (float, int, boolean)
    output = {'Test Statistic': x[0], 
              'P-value': x[1], 
              'Number of lags': x[2], 
              'Number of observations': x[3],
              f'Reject (signif. level {signif})': x[1] < signif }

    for key, val in x[4].items():
         output[f'Critical value {key}'] = val
    
    return pd.Series(output)

# %%
df_logret_adf = df_logret_abs.apply(lambda x: adfuller_test(np.array(x)), axis=0)
df_vol_adf = df_vol.apply(lambda x: adfuller_test(np.array(x)), axis=0)
df_logret_adf.head()
#df_vol_adf.head()
# Out:
#                             Binance_Coin   Bitcoin Bitcoin_Cash Bitcoin_SV  \
# Test Statistic                 -4.495731 -4.035716    -4.942127  -5.718945
# P-value                           0.0002  0.001235     0.000029   0.000001
# Number of lags                         6        10            6          3
# Number of observations               344       340          344        347
# Reject (signif. level 0.05)         True      True         True       True
#
#                                Cardano  Chainlink Crypto_com_Coin       EOS  \
# Test Statistic              -16.572584 -16.059405       -3.286203 -7.046448
# P-value                            0.0        0.0        0.015507       0.0
# Number of lags                       0          0              16         3
# Number of observations             350        350             334       347
# Reject (signif. level 0.05)       True       True            True      True
#
#                              Ethereum Huobi_Token  Litecoin    Monero  \
# Test Statistic              -5.312662    -6.76409 -6.719079  -4.07046
# P-value                      0.000005         0.0       0.0  0.001083
# Number of lags                      7           3         3         9
# Number of observations            343         347       347       341
# Reject (signif. level 0.05)      True        True      True      True
#
#                                   NEO    Stellar    Tether     Tezos  \
# Test Statistic              -3.888246 -15.821224 -6.757029 -7.267776
# P-value                      0.002123        0.0       0.0       0.0
# Number of lags                      9          0         3         3
# Number of observations            341        350       347       347
# Reject (signif. level 0.05)      True       True      True      True
#
#                                  TRON UNUS_SED_LEO  USD_Coin       XRP
# Test Statistic              -6.577143    -7.775443 -2.244799 -5.474674
# P-value                           0.0          0.0  0.190389  0.000002
# Number of lags                      3            2        15         7
# Number of observations            347          348       335       343
# Reject (signif. level 0.05)      True         True     False      True

# %%
import warnings
warnings.filterwarnings('ignore')

def archmodel(series):
    garch11 = arch_model(series, p=1, q=1)
    res = garch11.fit(update_freq=10)
    return pd.Series(res.params)

df_ret_garch = df_ret.apply(lambda x: archmodel(np.array(x)), axis=0)
df_vol_garch = df_vol.apply(lambda x: archmodel(np.array(x)), axis=0)
df_ret_garch.head()
#df_vol_garch.head()
# Out:
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 999.7108790101602
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 999.7108790101602
#             Iterations: 10
#             Function evaluations: 59
#             Gradient evaluations: 10
# Iteration:     10,   Func. Count:     57,   Neg. LLF: 923.5446604239692
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 923.5446605615932
#             Iterations: 10
#             Function evaluations: 57
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1043.2177241297209
#             Iterations: 9
#             Function evaluations: 53
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1164.6427500722675
#             Iterations: 9
#             Function evaluations: 50
#             Gradient evaluations: 9
# Iteration:     10,   Func. Count:     57,   Neg. LLF: 1075.4342180607953
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1075.4342180608253
#             Iterations: 10
#             Function evaluations: 57
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1129.9830138526395
#             Iterations: 8
#             Function evaluations: 50
#             Gradient evaluations: 8
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 992.6751615490626
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 992.6751615490626
#             Iterations: 11
#             Function evaluations: 63
#             Gradient evaluations: 11
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1025.8751367706627
#             Iterations: 7
#             Function evaluations: 42
#             Gradient evaluations: 7
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 1017.5644633981583
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1017.5644633982945
#             Iterations: 10
#             Function evaluations: 59
#             Gradient evaluations: 10
# Iteration:     10,   Func. Count:     58,   Neg. LLF: 945.6628163745465
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 945.6628163745465
#             Iterations: 11
#             Function evaluations: 62
#             Gradient evaluations: 11
# Iteration:     10,   Func. Count:     60,   Neg. LLF: 1006.9158711736582
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1006.9158711735673
#             Iterations: 10
#             Function evaluations: 60
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1005.3544790641599
#             Iterations: 9
#             Function evaluations: 54
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1059.2957140203023
#             Iterations: 9
#             Function evaluations: 52
#             Gradient evaluations: 9
# Iteration:     10,   Func. Count:     58,   Neg. LLF: 1019.5105368498453
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1019.5105368497411
#             Iterations: 10
#             Function evaluations: 58
#             Gradient evaluations: 10
# Iteration:     10,   Func. Count:     63,   Neg. LLF: 253.92456777482886
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 253.9245683066261
#             Iterations: 10
#             Function evaluations: 63
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1108.184157790151
#             Iterations: 7
#             Function evaluations: 44
#             Gradient evaluations: 7
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 1034.2467887456742
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1034.2467887456742
#             Iterations: 11
#             Function evaluations: 63
#             Gradient evaluations: 11
# Iteration:     10,   Func. Count:     57,   Neg. LLF: 643.0359799612866
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 643.0359799612604
#             Iterations: 10
#             Function evaluations: 57
#             Gradient evaluations: 10
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 189.34328914643407
#             Iterations: 11
#             Function evaluations: 45
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 946.3394733157861
#             Iterations: 9
#             Function evaluations: 53
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
# C:\Users\Tharun\anaconda3\lib\site-packages\arch\univariate\base.py:753: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#             Current function value: 5953.468562800728
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5416.072451047798
#             Iterations: 4
#             Function evaluations: 22
#             Gradient evaluations: 4
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5911.472415599237
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5759.2510556812695
#             Iterations: 7
#             Function evaluations: 39
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7908.557174069838
#             Iterations: 5
#             Function evaluations: 27
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6658.4601495056095
#             Iterations: 7
#             Function evaluations: 40
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7152.548765096561
#             Iterations: 6
#             Function evaluations: 33
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7391.43223374453
#             Iterations: 7
#             Function evaluations: 40
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6474.142806720332
#             Iterations: 8
#             Function evaluations: 43
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6450.962596645497
#             Iterations: 4
#             Function evaluations: 22
#             Gradient evaluations: 4
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6395.962508145702
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6278.3151981540905
#             Iterations: 9
#             Function evaluations: 50
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6293.909145938794
#             Iterations: 6
#             Function evaluations: 34
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8120.344909628915
#             Iterations: 4
#             Function evaluations: 22
#             Gradient evaluations: 4
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8656.259228675475
#             Iterations: 5
#             Function evaluations: 27
#             Gradient evaluations: 5
# Iteration:     10,   Func. Count:     55,   Neg. LLF: 6496.607487900523
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6496.607487900462
#             Iterations: 10
#             Function evaluations: 55
#             Gradient evaluations: 10
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8879.873552759795
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5632.833601328487
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7314.748253890954
#             Iterations: 7
#             Function evaluations: 38
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8195.225411964313
#             Iterations: 7
#             Function evaluations: 35
#             Gradient evaluations: 7
#           Binance_Coin   Bitcoin  Bitcoin_Cash  Bitcoin_SV   Cardano  \
# mu            0.210851  0.273054      0.034143   -0.161004  0.497689
# omega         0.931068  0.766258      0.795081    4.118419  4.750346
# alpha[1]      0.203475  0.207603      0.155344    0.271799  0.129684
# beta[1]       0.787854  0.792397      0.844656    0.728201  0.717564
#
#           Chainlink  Crypto_com_Coin       EOS  Ethereum  Huobi_Token  \
# mu         0.666351         0.549151 -0.096870  0.375206     0.169179
# omega      1.259459         1.148955  0.563681  0.768632     0.801314
# alpha[1]   0.083554         0.073048  0.138946  0.115826     0.211686
# beta[1]    0.897439         0.872993  0.861054  0.867676     0.788314
#
#           Litecoin    Monero       NEO   Stellar    Tether     Tezos  \
# mu        0.152438  0.379062  0.442930  0.131334  0.048800  0.362425
# omega     1.311303  0.711316  2.068518  3.651085  0.025647  1.130707
# alpha[1]  0.147127  0.116225  0.110080  0.120715  0.358763  0.096316
# beta[1]   0.808816  0.864393  0.821105  0.708991  0.641237  0.879206
#
#               TRON  UNUS_SED_LEO  USD_Coin       XRP
# mu        0.252735      0.067124 -0.001062  0.016300
# omega     1.100177      0.558186  0.000003  1.484955
# alpha[1]  0.197799      0.227565  0.123945  0.187855
# beta[1]   0.795744      0.568023  0.876470  0.741546

# %%
df_ret[['Tether']].plot(figsize=(15, 10)).axhline(color='black', linewidth=2)

# %%
df_ret[['Bitcoin']].plot(figsize=(15, 10)).axhline(color='black', linewidth=2)

# %%
df_ret[['USD_Coin','XRP','Bitcoin_Cash']].plot(figsize=(15, 10)).axhline(color='black', linewidth=2)

# %%
df_ret[['Crypto_com_Coin']].plot(figsize=(15, 10)).axhline(color='black', linewidth=2)

# %%
df_ret_garch[['Bitcoin','Tether']]
# Out:
#            Bitcoin    Tether
# mu        0.273054  0.048800
# omega     0.766258  0.025647
# alpha[1]  0.207603  0.358763
# beta[1]   0.792397  0.641237

# %%
import warnings
warnings.filterwarnings('ignore')

def archmodel(series):
    tarch11 = arch_model(series, p=1, q=1, power=1.0)
    res = tarch11.fit(update_freq=10)
    return pd.Series(res.params)

df_ret_tarch = df_ret.apply(lambda x: archmodel(np.array(x)), axis=0)
df_vol_tarch = df_vol.apply(lambda x: archmodel(np.array(x)), axis=0)
df_ret_tarch.head()
#df_vol_tarch.head()
# Out:
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 1005.8742811052673
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1005.8742817686705
#             Iterations: 10
#             Function evaluations: 59
#             Gradient evaluations: 10
# Iteration:     10,   Func. Count:     61,   Neg. LLF: 927.2087592148193
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 927.2087595335602
#             Iterations: 10
#             Function evaluations: 61
#             Gradient evaluations: 10
# Iteration:     10,   Func. Count:     61,   Neg. LLF: 1045.1261000735212
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1045.1261000735212
#             Iterations: 11
#             Function evaluations: 65
#             Gradient evaluations: 11
# Iteration:     10,   Func. Count:     60,   Neg. LLF: 1176.2961550099863
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1176.2953107209642
#             Iterations: 16
#             Function evaluations: 102
#             Gradient evaluations: 16
# Iteration:     10,   Func. Count:     60,   Neg. LLF: 1075.1694097501231
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1075.1693337202876
#             Iterations: 13
#             Function evaluations: 75
#             Gradient evaluations: 13
# Iteration:     10,   Func. Count:     63,   Neg. LLF: 1124.994371389182
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1124.9899311134252
#             Iterations: 17
#             Function evaluations: 99
#             Gradient evaluations: 17
# Iteration:     10,   Func. Count:     64,   Neg. LLF: 993.4731759246805
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 993.4729695691375
#             Iterations: 12
#             Function evaluations: 73
#             Gradient evaluations: 12
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 1026.5608712067
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1026.559437522096
#             Iterations: 16
#             Function evaluations: 120
#             Gradient evaluations: 16
# Iteration:     10,   Func. Count:     61,   Neg. LLF: 1018.5634841305913
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1018.5634841246934
#             Iterations: 12
#             Function evaluations: 70
#             Gradient evaluations: 11
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 937.5696942376247
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 937.5696942376247
#             Iterations: 11
#             Function evaluations: 63
#             Gradient evaluations: 11
# Iteration:     10,   Func. Count:     62,   Neg. LLF: 1006.803045115185
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1006.8028207371015
#             Iterations: 13
#             Function evaluations: 76
#             Gradient evaluations: 13
# Iteration:     10,   Func. Count:     60,   Neg. LLF: 1005.7472886078942
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1005.7472886078942
#             Iterations: 11
#             Function evaluations: 64
#             Gradient evaluations: 11
# Iteration:     10,   Func. Count:     62,   Neg. LLF: 1057.6704636826921
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1057.6704580340038
#             Iterations: 12
#             Function evaluations: 71
#             Gradient evaluations: 12
# Iteration:     10,   Func. Count:     63,   Neg. LLF: 1055.2489836726231
# Iteration:     20,   Func. Count:    115,   Neg. LLF: 1022.3263038217459
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1022.3153696712277
#             Iterations: 27
#             Function evaluations: 154
#             Gradient evaluations: 27
# Iteration:     10,   Func. Count:     61,   Neg. LLF: 254.11312133480553
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 254.11312133480553
#             Iterations: 11
#             Function evaluations: 65
#             Gradient evaluations: 11
# Iteration:     10,   Func. Count:     58,   Neg. LLF: 1108.8723271622314
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1108.8722553162943
#             Iterations: 13
#             Function evaluations: 76
#             Gradient evaluations: 13
# Iteration:     10,   Func. Count:     61,   Neg. LLF: 1037.489800118143
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1037.4897981551305
#             Iterations: 12
#             Function evaluations: 71
#             Gradient evaluations: 12
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 642.9418699262909
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 642.9416742381866
#             Iterations: 13
#             Function evaluations: 73
#             Gradient evaluations: 13
# Iteration:     10,   Func. Count:     62,   Neg. LLF: 228.6399269251712
# Iteration:     20,   Func. Count:    134,   Neg. LLF: 229.3417171260561
# Iteration:     30,   Func. Count:    239,   Neg. LLF: 44620979.03333072
# Iteration:     40,   Func. Count:    346,   Neg. LLF: 340.9543464317493
# Iteration:     50,   Func. Count:    420,   Neg. LLF: 230.91448062998722
# Iteration:     60,   Func. Count:    477,   Neg. LLF: 229.28979960973663
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 228.56749218192255
#             Iterations: 68
#             Function evaluations: 513
#             Gradient evaluations: 64
# Iteration:     10,   Func. Count:     62,   Neg. LLF: 949.0498362398632
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 949.049760332357
#             Iterations: 13
#             Function evaluations: 76
#             Gradient evaluations: 13
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5960.397418420949
#             Iterations: 7
#             Function evaluations: 39
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5419.55635669953
#             Iterations: 5
#             Function evaluations: 29
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5916.054358104646
#             Iterations: 8
#             Function evaluations: 44
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5766.240816526083
#             Iterations: 7
#             Function evaluations: 39
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7908.11208375344
#             Iterations: 5
#             Function evaluations: 28
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6668.6796434815005
#             Iterations: 7
#             Function evaluations: 39
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7146.066511109426
#             Iterations: 8
#             Function evaluations: 43
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7401.338179638747
#             Iterations: 8
#             Function evaluations: 43
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6471.810551069054
#             Iterations: 9
#             Function evaluations: 48
#             Gradient evaluations: 9
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6457.42178052903
#             Iterations: 7
#             Function evaluations: 39
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6393.223348829288
#             Iterations: 5
#             Function evaluations: 28
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6288.413986506706
#             Iterations: 8
#             Function evaluations: 43
#             Gradient evaluations: 8
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6296.89283853829
#             Iterations: 6
#             Function evaluations: 32
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8116.262889868212
#             Iterations: 6
#             Function evaluations: 33
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8655.163634688084
#             Iterations: 7
#             Function evaluations: 37
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6506.1769997551455
#             Iterations: 7
#             Function evaluations: 38
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8876.913215274597
#             Iterations: 7
#             Function evaluations: 39
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5628.172611703619
#             Iterations: 6
#             Function evaluations: 32
#             Gradient evaluations: 6
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7318.7402594747555
#             Iterations: 7
#             Function evaluations: 39
#             Gradient evaluations: 7
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 8188.273654078006
#             Iterations: 7
#             Function evaluations: 36
#             Gradient evaluations: 7
#           Binance_Coin   Bitcoin  Bitcoin_Cash  Bitcoin_SV   Cardano  \
# mu            0.297901  0.429464      0.321970   -0.275000  0.515367
# omega         0.216299  0.172379      0.190067    0.799705  0.670356
# alpha[1]      0.157946  0.124687      0.111290    0.251201  0.134378
# beta[1]       0.842054  0.875313      0.888710    0.748799  0.782539
#
#           Chainlink  Crypto_com_Coin           EOS  Ethereum  Huobi_Token  \
# mu         0.771133         0.592405  1.214248e-08  0.387654     0.057706
# omega      0.178395         0.175595  1.618820e-01  0.149276     0.185520
# alpha[1]   0.088666         0.073881  9.836968e-02  0.094319     0.141631
# beta[1]    0.911334         0.910901  9.016303e-01  0.905681     0.858369
#
#           Litecoin    Monero       NEO   Stellar    Tether     Tezos  \
# mu        0.335173  0.583648  0.327276  0.054933  0.042645  0.355011
# omega     0.162485  0.112782  0.282858  1.013427  0.066511  0.192569
# alpha[1]  0.114362  0.088257  0.096735  0.141253  0.284357  0.114127
# beta[1]   0.885638  0.911743  0.876893  0.675934  0.715643  0.885873
#
#               TRON  UNUS_SED_LEO  USD_Coin       XRP
# mu        0.105797      0.055737  0.000001 -0.038575
# omega     0.208101      0.374826  0.024543  0.124569
# alpha[1]  0.132521      0.197157  0.145420  0.096223
# beta[1]   0.867479      0.619149  0.854580  0.903777
